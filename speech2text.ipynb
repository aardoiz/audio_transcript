# %%
! pip install huggingsound

# %%
from huggingsound import SpeechRecognitionModel

model = SpeechRecognitionModel("jonatasgrosman/wav2vec2-large-xlsr-53-spanish")
# Out:
# 05/12/2022 11:38:33 - INFO - huggingsound.speech_recognition.model - Loading model...
# Downloading:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/262 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/380 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tr = []
for i in range(1,8):
  audio_paths = [f"drive/MyDrive/audio_tracks/yay_{i}.wav"]
  transcriptions = model.transcribe(audio_paths)
  tr.append(transcriptions)
# Out:
# 100%|██████████| 1/1 [00:31<00:00, 31.64s/it]
# 100%|██████████| 1/1 [00:31<00:00, 31.17s/it]
# 100%|██████████| 1/1 [00:30<00:00, 30.27s/it]
# 100%|██████████| 1/1 [00:30<00:00, 30.40s/it]
# 100%|██████████| 1/1 [00:30<00:00, 30.08s/it]
# 100%|██████████| 1/1 [00:30<00:00, 30.63s/it]
# 100%|██████████| 1/1 [00:06<00:00,  6.52s/it]

# %%
for eee in tr:
  print(eee[0]['transcription'])
# Out:
# bienvenidos al criterio catorce soy alfonso y vamos a hablar de la accesibilidad del contenido indovisual en esta sección nos vamos a centrar en las técnicas que nos permiten que nuestros contenidos aedovisuales sean accesibles a todos los alumnos el índice que vamos a seguir es lo que teneis aquiar da izquierdaen primer lugar vamos a hablar del contraste en las imágenes todas las imágenes necesitan contraste es decir no podemos hacer como el ejemplo de la izquierda meter una imagen sobre un fondo del mismo color
# necisitamos que el fondo sea distinto para que la imagen se puede istinguir sin problemas además como podemos ver e las dos imágenes llevan un texto alternativo lo que nos lleva el siguiente puntotodas las imágenes necesitante hesta alternativo esto es importante ya que ciertos  alumnos van a tener que usar dispositivos que les disten el contenido automáticamente ya que tienen discapacidad visual si llegan a una imagen como la izquierda el probamava a decir simplemente imagenpero si llegan a una imagen como la derecha que tiene un testo alternativo
# va describir la imagen kigy pájaro comien un kibo y frutatres alternativa a los contenidos audiovisuales cuando inclimos este tipo de contenidos en nuestros materiales es de evitar importancia que prepare más alternativas para aquellos alumnos con problemas para ceder a este tipo de materiales en este caso emohe incluido un gif a la izquierdo y una descripción a la derecha que además está en formato audio para ofrecer una nueva alternativa a este tipo de alumnosen la imagen de la izquierda
# hemo sado michaely scott de the office haciendo parcureel un cuatro habla de los controles en la reproducción de nuestros materiales como buen ejemplo de este punto tenemos elos videos y yotube que tienen muy buen parair decontrol para controlar nuestros videos es importante que los videos nos reproduccan automáticamente y que si es posible que contengan sub títulos o una transcleccióna su vez vamos a ver las opciones de audionueros
# ontenidos adevisores tienen que tener este tipo deaciones para que los usuarios puedan bajar el volumen subir el volumen o silenciar los videos respecto al punto seis la precaución con el brillo de las imágenes e necesario que nuestros contenidos no contengan imágenes peligrosas para las personas fotosensibles como ejemplo de esto tenemos la imagen de la izquierdaes más que adecuado obligatorio que las imágenes que incluyamos no tiengan ningún efecto visual de luz extremo por ejemplo la imagen del atardecer de la derecha en málaga
# último llegamos al punto final de criterio catorce la necesidad de la esistencia de alternativas a las alertas de los contanidos audiovisuales es común que cuando estamos contenido diovisual haya alertas tipos sonoras o tipos ovisuales cuando esto es posible es necesario que incluyamos este tipo de alertas en nuestros contanidos alternativos en este caso estamos haciendo esto cuando iponemos que es importante en el texto que que marcar alerta en las alternativas a estos materialesy con esto hemos terminado
# el curso sobre el criterio catorce muchisimás gracias por su atención eso y alfonso adoyz y cualquier duda pueden conttar contactar conmigo por correl
